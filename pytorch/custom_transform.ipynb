# %%
import cv2
import matplotlib.pyplot as plt
from torchvision import transforms as T

# %%
class CLAHE(object):
    def __init__(self,clipLimit,tileGridSize):
        self.clipLimit = clipLimit
        self.tileGridSize = tileGridSize
        
        self.clahe = cv2.createCLAHE(clipLimit=self.clipLimit,
                                     tileGridSize=(self.tileGridSize,self.tileGridSize))
    
    def __call__(self,sample):
        return self.clahe.apply(sample)

# %%
clahe=CLAHE(4,8)
transforms = T.Compose([clahe,
                        T.ToPILImage(),
                        T.Resize((480,960))])

# %%
plt.imshow(sample_pano,cmap='bone')
plt.show()

# %%
plt.imshow(transforms(sample_pano),cmap='bone')
plt.show()
